# %%
import pandas as pd
import json
import spacy
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
#Read the speed-dating dataset
sd_data = pd.read_csv('data/train_chat.csv')

# %%
for i in range(20):
  print(sd_data['Message'][i])
# Out:
# How are you today?
# fine.  how are you?
# I am good, enjoying the holidays. Do you celebrate Christmas?
# as much as i celebrate any holiday :-)|I enjoy cooking a lot in the winter time|so around XXmas time, i start cooking a lot more|especially soups.|do you like to cook?
# I have two small children and my 5 year old is really enjoying finding "elf" this year and is anticipating sanat coming to visit. Are you from aroudn here or will be heading home for the holidays?|Yes, but I finsd I am not doing it as often these days! What is your favorite foods?
# this is essentially my home now.  no travel for me.
# Me as well, I was raised just outside Boston, so I host at our condo in Somerville. Where do you live?
# i like soups: kale-white bean-bacon is one of my favs.
# Are you a student here at harvard?
# i also like to make a beef okra stew.|not a student|i live in Arlington.|do you travel much?
# Okra, wow that is an interesting one, I haven't tried any recipes with that yet!
# ...

# %%
with open(r'data/summer_wild_evaluation_dialogs.json') as f: 
    d = json.load(f) 

pc_data = pd.json_normalize(data = d, 
                            record_path ='dialog') 
pc_data.head(5)
# Out:
#    id        sender                                               text  \
# 0   0  participant2           I love iphone! i just bought new iphone!
# 1   1  participant1     Thats good for you, i'm not very into new tech
# 2   2  participant2  I am a college student and i am a college student
# 3   3  participant1               I am go to gym and live on donations
# 4   4  participant2               I am a vegan and i am in the midwest
#
#   sender_class
# 0          Bot
# 1        Human
# 2          Bot
# 3        Human
# 4          Bot

# %%
nlp = spacy.load('en_core_web_sm')

def extract_questions(dataset):
    q_list = []
    for i in range(len(dataset)):
      #text = metadata2['Message'][i] #speed-dating dataset
      text = dataset[i] #persona chat dataset
      text_sentences = nlp(text)
      for sentence in text_sentences.sents:
        #print(sentence.text)
        for token in sentence:
          if token.text == '?':
            q_list.append(sentence)
    return q_list

# %%
question_list_sd = extract_questions(sd_data['Message'])
print(question_list_sd)
# Out:
# [How are you today?, how are you?, Do you celebrate Christmas?, more|especially soups.|do you like to cook?, What is your favorite foods?, Where do you live?, Are you a student here at harvard?, you travel much?, How about you?, been to the Tennement Museum in NYC?, Are you an artist?, Have you seen the new shoe there?, who/what is it?, did you go to art school?, Do you do installations with your video work?, What do you do by day?, college?|what do you do now?, which do you prefer?, I play guitar, draw, and run my mouth on a lot of topics.|and u?, whoops.|is your shop in cambridge?, Trump an idiot?, Where do you think the next terrorist attack is going to occur?, hello|what things you enjoy doing?, are you a boston native ?, have you been in other countries?|no, I am from Colombia, and you?, how do you like it here ?, how was your mynamar trip ?, how long have you been living in Boston?, I have been here for two years|what do you do in boston ?, I work in photography and you?, have 
# ...

# %%
#TODO noun extraction of the questions
print(len(question_list_sd))
# Out:
# 4511

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. U.K. PROPN NNP compound X.X. False False
# startup startup NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %%
nlp = spacy.load('en_core_web_sm')

question_list = []

for i in range(len(pc_data.text)):
  #text = metadata2['Message'][i] #speed-dating dataset
  text = pc_data.text[i] #persona chat dataset
  text_sentences = nlp(text)
  for sentence in text_sentences.sents:
    #print(sentence.text)
    for token in sentence:
      if token.text == '?':
        question_list.append(sentence)


print(question_list)
# Out:
# [Dogs or vegan in office?, What do you do?, Hello, how are you?, what is your name ?, What’s up?, where are you from?, Where is susan?, Where do you live?, In Cyprus?, I'm on a log, and you're in Cyprus?, WHAT ARE YOU, A native OR SOMETH ing?, Do you have any siblings?, Yeah, and you?, What kind of music?, Do you have dogs?, Where do you live?, I live in alabama, where are you from?, what do you want me to say?, are you ok?, that is cool , i am a dancer , and i am a teacher , and you ?, So you like it or hate it?, Where do you live?, Close to mountains?, Hi, is anyone on ohter end?, Is it interesting?, Do what?, What are you doing now?, do you have any hobbies ?, And you?, Do you like music?, What?, What is that?, MUSIC PLAYS What is that sound?, how old are you?, how old are you?, are you a musician?, How old are you?, YOU DON'T like STEAK?, Are you a cook or what?, Can we talk about anything else?, And you?, What tree?, "What To Do If You Meet a Mountain Lion"?, how old are you?, a
# ...

# %%
from spellchecker import SpellChecker
spell = SpellChecker()

noun_dict = {}
for i in range(len(question_list)):
  text = question_list[i] #persona chat dataset
  
  for token in text:
      #print(token.text, token.pos_, token.dep_)
      if token.pos_ == "NOUN":
        #TODO lemmatization
        
        corr = spell.correction(token.text)


        if corr not in noun_dict.keys():
          noun_dict[corr] = 1
        else:
          noun_dict[corr] +=1
        #noun_list.append(token.text)
        print(text, "-", corr)
        #print(token.text)
# Out:
# Dogs or vegan in office? - vegan
# Dogs or vegan in office? - office
# what is your name ? - name
# I'm on a log, and you're in Cyprus? - log
# WHAT ARE YOU, A native OR SOMETH ing? - cometh
# WHAT ARE YOU, A native OR SOMETH ing? - ing
# Do you have any siblings? - siblings
# What kind of music? - kind
# What kind of music? - music
# Do you have dogs? - dogs
# that is cool , i am a dancer , and i am a teacher , and you ? - dancer
# that is cool , i am a dancer , and i am a teacher , and you ? - teacher
# Close to mountains? - mountains
# Hi, is anyone on ohter end? - end
# do you have any hobbies ? - hobbies
# Do you like music? - music
# MUSIC PLAYS What is that sound? - sound
# are you a musician? - musician
# Are you a cook or what? - cook
# What tree? - tree
# are you a sportsman? - sportsman
# a horse? - horse
# what is your job? - job
# what do you do for living? - living
# Do you know the man standing there? - man
# Do you know the man standing there? - man
# ...

# %%
#print(noun_dict)
import operator
from spellchecker import SpellChecker

noun_dict2 = sorted(noun_dict.items(), key=operator.itemgetter(1))#, reverse=True)
print(noun_dict2)
"""
spell = SpellChecker()
# find those words that may be misspelled
for noun, freq in noun_dict2:
    #print(noun)
    misspelled = spell.unknown(noun)
    for word in misspelled:
        # Get the one `most likely` answer
        print(spell.correction(word))
        print(noun) """
# Out:
# [('cometh', 1), ('ing', 1), ('end', 1), ('sportsman', 1), ('message', 1), ('indoors', 1), ('teaching', 1), ('sand', 1), ('look', 1), ('a.m.', 1), ('medicine', 1), ('ask', 1), ('partners', 1), ('habits', 1), ('once', 1), ('malls', 1), ('Towns', 1), ('smells', 1), ('faces', 1), ('thank', 1), ('readers', 1), ('Armpits', 1), ('pop', 1), ('metall', 1), ('do', 1), ('hill', 1), ('stories', 1), ('streams', 1), ('Reality', 1), ('albums', 1), ('Sports', 1), ('hairdresser', 1), ('spiderman', 1), ('therapist', 1), ('Cars', 1), ('Librarians', 1), ('drinking', 1), ('pancakes', 1), ('energy', 1), ('drinks', 1), ('grandma', 1), ('pants', 1), ('toy', 1), ('case', 1), ('hearing', 1), ('biography', 1), ('point', 1), ('Home', 1), ('storm', 1), ('Husband', 1), ('drama', 1), ('marathon', 1), ('grill', 1), ('hero', 1), ('sailor', 1), ('boat', 1), ('helmet', 1), ('singers', 1), ('audition', 1), ('anyone', 1), ('software', 1), ('developer', 1), ('prices', 1), ('humans', 1), ('result', 1), ('walk', 1), ('expe
# ...

# %% [markdown]
# #Trying to extract question and answer pairs

# %%
temp_list = []
question_added = False
for i in range(len(pc_data.text)):
    #text = metadata2['Message'][i] #speed-dating dataset
    text = pc_data.text[i] #persona chat dataset
    text_sentences = nlp(text)
    curr = ' '
    for sentence in text_sentences.sents:    
        if question_added and curr != text_sentences.sents:
            temp_list.append((temp,sentence))
        question_added = False
        #print(sentence.text)
        for token in sentence:
            curr = text_sentences.sents
            if token.text == '?':
                temp = sentence
                question_added = True
                #temp_list.append(sentence)

print(temp_list)
# Out:
# [(Dogs or vegan in office?, I am a vegetarian), (What do you do?, I love painting, i love to paint), (Hello, how are you?, what is your name ?), (what is your name ?, hello), (What’s up?, Thank you how are you), (where are you from?, Fine.), (Where is susan?, Um, I  I have to talk to Edie.), (Where do you live?, I I'm building a new house.), (In Cyprus?, I'm on a log, and you're in Cyprus?), (I'm on a log, and you're in Cyprus?, Lol), (WHAT ARE YOU, A native OR SOMETH ing?, I like action movies, movies, movies, movies, movies,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,), (Do you have any siblings?, Yeah, and you?), (Yeah, and you?, I am good, just listening to some music), (What kind of music?, Country music, country, country, jazz), (Do you have dogs?, Yes, i have two dogs, and a cat.), (Where do you live?, I live in the midwest), (I live in alabama, where are you from?, I work from home), (what do you want me to say?, hey), (are you ok?, i love animals , i have a dog , and a dog .), (tha
# ...

# %%
temp_sentence =""
output_line = pc_data.text[0]
qa_pairs = []
for i in range(1,len(pc_data.text[1:])):
    input_line = output_line
    output_line = pc_data.text[i]
    question_exist = False
    answer_exist = False
    if pc_data.sender[i-1] != pc_data.sender[i]:
        #print("Not same")
        #print(input_line, " , ", output_line)
        
        sents = sent_tokenize(input_line)
        for sentence in sents:
            if len(sentence) >1:
                tokens = word_tokenize(sentence)
                if len(tokens) > 3:
                  for token in tokens:
                      if token == '?':
                          input_line = sentence
                          #print(sentence, "Question")
                          question_exist = True
        sents = sent_tokenize(output_line)
        if question_exist:
            temp_sentence = ""
            token_count = 0
            for sentence in sents:
                if len(sentence) >1 and sentence != "Text is not given.":
                    tokens = word_tokenize(sentence)
                    for token in tokens:
                        if token == '.':
                            temp_sentence = sentence#temp_sentence + " " + sentence
                            token_count = token_count + len(tokens)
                            #print(sentence, "answer")
                            if token_count > 2: #no answer that just says yes or no
                              answer_exist = True
                    if answer_exist:
                      break

    
    if question_exist and answer_exist:
        print(input_line + " " + temp_sentence)
        qa_pairs.append(input_line + " " + temp_sentence)
# Out:
# where are you from? Until I told him I sold his condo.
# Where is susan? Um, I  I have to talk to Edie.
# Where do you live? I I'm building a new house.
# Do you have dogs? Yes, i have two dogs, and a cat.
# are you ok? i love animals , i have a dog , and a dog .
# So you like it or hate it? i like mountain climbing , but i also like to bike .
# Close to mountains? i like to draw , and draw , and draw , and draw , and draw , and paint , and draw , and draw , and paint .
# Is it interesting? i think it is .
# What are you doing now? i am not sure .
# do you have any hobbies ? Not really... i spend a lot of time at the hospital.
# how old are you? 'The Jazz Singer,' that's what.
# how old are you? (In Swedish) We have a visitor... Oskar.
# are you a musician? Cabaret Voltaire, those people.
# How old are you? Here, I'II put little feet on my hamburger.
# Are you a cook or what? But I think I like it.
# ...

# %%
temp_sentence =""
output_line = sd_data['Message'][0]
qa_pairs = []
for i in range(1,len(sd_data['Message'][1:])):
    input_line = output_line
    output_line = sd_data['Message'][i]
    
    question_exist = False
    answer_exist = False
    if sd_data['User'][i-1] != sd_data['User'][i]:
        #print("Not same")
        #print(input_line, " , ", output_line)
        input_line = input_line.replace('|', ', ')
        sents = sent_tokenize(input_line)
        for sentence in sents:
            if len(sentence) >1:
                tokens = word_tokenize(sentence)
                if len(tokens) > 3:
                  for token in tokens:
                      if token == '?':
                          input_line = sentence
                          #print(sentence, "Question")
                          question_exist = True
        output_line = output_line.replace('|', ', ')
        sents = sent_tokenize(output_line)
        if question_exist:
            temp_sentence = ""
            token_count = 0
            for sentence in sents:
                if len(sentence) >1 and sentence != "Text is not given.":
                    tokens = word_tokenize(sentence)
                    for token in tokens:
                        if token == '.':
                            temp_sentence = sentence#temp_sentence + " " + sentence
                            token_count = token_count + len(tokens)
                            #print(sentence, "answer")
                            if token_count > 2: #no answer that just says yes or no
                              answer_exist = True
                    if answer_exist:
                      break

    
    if question_exist and answer_exist:
        print(input_line +' ' + temp_sentence)
        qa_pairs.append(input_line +' ' + temp_sentence )
# Out:
# how are you? I am good, enjoying the holidays.
# as much as i celebrate any holiday :-), I enjoy cooking a lot in the winter time, so around XXmas time, i start cooking a lot more, especially soups., do you like to cook? I have two small children and my 5 year old is really enjoying finding "elf" this year and is anticipating sanat coming to visit.
# What is your favorite foods? this is essentially my home now.
# Where do you live? i like soups: kale-white bean-bacon is one of my favs.
# How about you? not really big into travel.
# NYC is fun, as well as p-town, what brings youi to those places?, Have yoiu been to the Tennement Museum in NYC? i love big cities (NYC), p-town is cool--lots of art there and good food.
# Are you an artist? i have not been to that museum.
# Have you seen the new shoe there? oh yeah, i heard about that.
# While I am not an artist, I went to MassArt for undgrad for graphic design and made some art there...did you go to art school? no art school for me.
# ...

# %%
import pandas as pd
df = pd.DataFrame(qa_pairs)
df.to_csv('persona-chat_preprocessed.csv', index=False)

# %%
ex_text = "Do you play any instruments?🙂"
import spacy
nlp = spacy.load('en_core_web_sm')


text_sentences = nlp(ex_text)
for sentence in text_sentences.sents:
    for token in sentence:
      print(token.text, token.pos_)
# Out:
# Do AUX
# you PRON
# play VERB
# any DET
# instruments NOUN
# ? PUNCT
# 🙂 PROPN

# %% [markdown]
# #Trying out the conceptnet API to find relations

# %%
import requests

for noun, freq in noun_dict2[0:10]:
    
    query_noun = noun
    api_path = 'http://api.conceptnet.io/query?start=/c/en/' + query_noun + '&rel=/r/IsA'
    obj = requests.get(api_path).json()
    #print(obj['edges'][0])

    #outer for traverses the edges, inner for traverses the content in the 'end' tag
    for j in range(len(obj['edges'])):
        print("Description:", obj['edges'][j]['surfaceText'])
        for i in obj['edges'][j]['end']:
            if i == 'label':
                print("Label:", obj['edges'][j]['end'][i]) 
            elif i == 'sense_label':
                print("Sense_label:", obj['edges'][j]['end'][i])
# Out:
# Description: [[A day]] is [[24 hours long]]
# Label: 24 hours long
# Description: [[day]] is a type of [[calendar day]]
# Label: calendar day
# Sense_label: n, time
# Description: [[day]] is a type of [[time unit]]
# Label: time unit
# Sense_label: n, time
# Description: [[day]] is a type of [[time period]]
# Label: time period
# Sense_label: n, time
# Description: [[day]] is a type of [[work time]]
# Label: work time
# Sense_label: n, time
# Description: [[day]] is a type of [[time]]
# Label: time
# Sense_label: n, time
# Description: [[day]] is a type of [[opportunity]]
# Label: opportunity
# Sense_label: n, state
# Description: [[day]] is a type of [[era]]
# Label: era
# Sense_label: n, time
# Description: [[A day]] is [[24 hours]]
# Label: 24 hours
# Description: None
# Label: period of time
# Description: None
# Label: day of reckoning
# Sense_label: n
# Description: [[name]] is a type of [[repute]]
# Label: repute
# Sense_label: n, state
# ...

# %%
print(len(noun_dict2))
# Out:
# 1318

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

# find those words that may be misspelled
misspelled = spell.unknown(['someth ing', 'is', 'hapenning', 'gitar','wahts'])

for word in misspelled:
    # Get the one `most likely` answer
    print(spell.correction(word))

    # Get a list of `likely` options
    print(spell.candidates(word))
# Out:
# guitar
# {'gita', 'guitar', 'sitar'}
# something
# {'something'}
# wants
# {'wants', 'watts', 'whats', 'waits', 'warts', 'wafts'}
# happening
# {'happening', 'henning', 'penning'}
# feeling
# {"feelin'", 'feeling', 'felin'}

# %%
liness = """-time-
What do you do in your spare time?
What do you like to do in your free time?
So what do you enjoy doing in your free time?
What do you do in your spare time?
what else do you like spending your time on?
What else do you like to do when you have free time?
What kind of things do you enjoy doing in your free time?
What kind of music do you like to listen to?
What kind of music do you like?
What is your favorite kind of music?
What's your favorite kind of food?
what kind of food do you like?
What kind of hobbies do you have?
What kind of hobbies do you like to do?
What kind of hobbies do you enjoy?
What kind of games do you play?
What kind of movies do you like?
what kind of shows do you like?
What kind of work do you do?
What kinds of things do you enjoy?
What kind of sports do you play?
What kind of books do you like to read?
what kinds of things do you enjoy doing?
